# %% [markdown]
# # Figure 3 paper figures
#
# This notebook generates the Figure 3 simulation panels for the unregulated `mudmut` baseline.

# %%
# %load_ext autoreload
# %autoreload 2

from figure3_paper_figures import confirm_sim51_configuration, generate_all

# %%
confirm_sim51_configuration()
# Out:
# {'div_rotation_mu': 0,
#  'div_rotation_sigma': 50,
#  'apical_axis_rotation_mu': 0,
#  'apical_axis_rotation_sigma': 30,
#  'critical_volume_mode': 0,
#  'dynamic_growth_rate_volume': 0,
#  'dynamic_growth_rate_nb_self_repression': 0,
#  'nb_nb_adhesion': 40,
#  'default_cell_cell_adhesion': 50}

# %%
generate_all()
# Out:
# {'figure3_mutant_examples_panel.png': PosixPath('/Users/skjannetty/bagherilab/neurogen-plane-rotation-analysis/docs/tex_draft/figures/figure3_mutant_examples_panel.png'),
#  'figure3_mutant_examples_panel.pdf': PosixPath('/Users/skjannetty/bagherilab/neurogen-plane-rotation-analysis/docs/tex_draft/figures/figure3_mutant_examples_panel.pdf'),
#  'figure3_endpoint_metrics_panel.png': PosixPath('/Users/skjannetty/bagherilab/neurogen-plane-rotation-analysis/docs/tex_draft/figures/figure3_endpoint_metrics_panel.png'),
#  'figure3_endpoint_metrics_panel.pdf': PosixPath('/Users/skjannetty/bagherilab/neurogen-plane-rotation-analysis/docs/tex_draft/figures/figure3_endpoint_metrics_panel.pdf'),
#  'figure3_mutant_hypothesis_panel.png': PosixPath('/Users/skjannetty/bagherilab/neurogen-plane-rotation-analysis/docs/tex_draft/figures/figure3_mutant_hypothesis_panel.png'),
# ...
